# %% [markdown]
# <a href="https://colab.research.google.com/github/nagasai2203/FMML-COURSE-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 09:28:22--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   208MB/s    in 0.3s
#
# 2023-05-03 09:28:23 (208 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4953   1705.06573v1  Statistical Relational Learning (SRL) methods ...    cs
# 35384  cs/0505080v1  In spite of the recent quick growth of the Evo...    cs
# 11225  1504.05880v1  Kernel methods are an extremely popular set of...  stat
# 5846    1206.6450v1  We study the problem of multivariate regressio...    cs
# 6017   1606.00856v1  This work includes all the technical details o...  stat
# ...             ...                                                ...   ...
# 32199   1212.4675v1  In this paper, we present our work on clusteri...    cs
# 31001  1802.00853v1  In this paper, we address the incremental clas...    cs
# 31793   1005.0047v1  In Bayesian machine learning, conjugate priors...    cs
# 14974  1604.01178v1  In this paper, we propose convolutional neural...    cs
# 11189   1412.1576v1  When building large-scale machine learning (ML...  stat
#
#                                                    title  year  \
# 4953   Online learnability of Statistical Relational ...  2017
# 35384  Dominance Based Crossover Operator for Evoluti...  2005
# 11225  Spectral Norm of Random Kernel Matrices with A...  2015
# 5846   Conditional Sparse Coding and Grouped Multivar...  2012
# 6017                Sequential Principal Curves Analysis  2016
# ...                                                  ...   ...
# 32199  Analysis of Large-scale Traffic Dynamics using...  2012
# 31001  Incremental Classifier Learning with Generativ...  2018
# 31793               A Geometric View of Conjugate Priors  2010
# 14974  Modeling Relational Information in Question-An...  2016
# 11189  LightLDA: Big Topic Models on Modest Compute C...  2014
#
#                                                 keywords
# 4953   [statistical, relational, detection, introduce...
# 35384  [evolutionary, objective, optimization, variat...
# 11225  [extremely, techniques, important, application...
# 5846   [multivariate, regression, naturally, regressi...
# 6017   [technical, sequential, principal, unsupervise...
# ...                                                  ...
# 32199  [clustering, prediction, congestion, configura...
# 31001  [incremental, classifier, catastrophic, forget...
# 31793  [conjugate, mathematical, convenience, conjuga...
# 14974  [convolutional, representation, sentences, rel...
# 11189  [attempted, industrial, thousands, practitione...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4953     [statistical, relational, detection, introduce...
# 35384    [evolutionary, objective, optimization, variat...
# 11225    [extremely, techniques, important, application...
# 5846     [multivariate, regression, naturally, regressi...
# 6017     [technical, sequential, principal, unsupervise...
#                                ...
# 21763    [algorithms, resolution, estimation, adequatel...
# 18493    [artificial, intelligence, themselves, situati...
# 22586    [technique, spatiotemporal, energypower, predi...
# 29858    [variational, optimization, assumption, estima...
# 13971    [abstraction, challenging, sequences, understa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8741 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="38bf0df0-4eaf-4714-b13b-7ce8c692c134" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38bf0df0-4eaf-4714-b13b-7ce8c692c134")) {                    Plotly.newPlot(                        "38bf0df0-4eaf-4714-b13b-7ce8c692c134",                        [{"x":["significant","analytically","tentative","knowledge","solutions","application","tractable","impossible","statistical","algorithms","learnability","detection","variables","relational","experimental","expressiveness","introduced","predictors","stability","theoretical","definitions","representative","operational","overarching","supervision","nevertheless","requirements","mathematical","framework","comprehensive","formulated","monitoring","contradictory","variation","objective","benchmark","conclusions","individual","potential","dominates","acceleration","exceptions","evolutionary","operators","individuals","restrictions","different","particular","dominated","introduces","crossover","restriction","population","validated","optimization","generating","recombination","constrained","preferably","dominance","offspring","asymptotic","traditional","outperforms","approaches","independent","important","constructed","practical","parametric","restrictive","techniques","distortion","dimensional","technique","regression","extremely","evaluating","performing","supported","coefficients","returning","developed","performances","contribution","functions","regularly","realistic","releasing","scenarios","applications","polynomials","attribute","combination","structure","properties","algorithm","intuition","conditional","computational","neuroscience","predictive","covariate","information","procedure","estimated","conditioned","naturally","simulation","dictionary","multivariate","experiments","parameter","successfully","technical","curvilinear","constraints","modalities","polynomial","illustrates","extraction","appropriate","introducing","minimization","interpreted","identified","generalization","principal","dimensionality","originated","projection","decorrelation","dedicated","frontiers","nonlinear","invertible","reduction","alternatives","corresponding","distances","philosophy","substantially","sequential","unsupervised","companion","injecting","disentangling","bottleneck","minimizing","activations","interpretation","representations","alternative","statistics","correlation","equivalent","explicitly","minimality","criterion","lagrangian","representation","overfitting","therefore","predicting","transitions","emergence","underfitting","invariant","established","regularizing","architecture","implicitly","memorization","invariance","principles","searching","engineering","exhaustive","automatically","demonstrated","prediction","necessarily","efficient","predictions","negligible","classification","complexity","superiority","interactions","subsequently","uniformly","empirically","structures","approximately","approximate","programming","formulations","computation","discussed","treewidth"],"y":[220,12,4,292,161,224,32,23,171,541,8,368,151,37,384,8,141,12,33,139,20,43,13,2,45,23,62,71,547,52,42,39,2,64,170,212,18,119,132,2,10,4,81,48,47,24,728,291,16,69,9,10,53,38,328,91,4,58,2,8,2,20,170,263,430,138,384,59,132,38,9,370,18,177,245,123,42,62,83,21,27,1,199,33,74,223,2,57,2,87,433,7,40,139,355,224,818,19,102,277,11,56,7,718,116,68,22,56,74,49,29,582,127,79,42,1,170,30,55,9,155,84,62,60,20,44,103,34,55,2,49,1,14,0,51,1,119,15,128,29,5,36,72,128,1,1,6,25,41,20,64,222,82,76,91,62,68,2,53,10,333,27,152,76,13,16,4,65,57,6,224,28,4,23,29,28,50,14,184,99,226,19,389,85,11,520,236,42,75,38,17,72,130,27,106,132,18,153,52,4],"type":"bar"},{"x":["significant","analytically","tentative","knowledge","solutions","application","tractab ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7866666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Computer</span> <span style=''>vision</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>the</span> <span style=''>non</span> <span style=''>invasive</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148134);'>assessment</span> <span style=''>of</span> <span style=''>autism</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behavioral</span> <span style=''>markers</span> <br/><br/><span style=''>The</span> <span style=''>early</span> <span style='background-color:rgba(0, 255, 0, 0.5692963752665245);'>detection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>developmental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disorders</span> <span style=''>is</span> <span style=''>key</span> <span style=''>to</span> <span style=''>child</span> <span style=''>outcome</span> <span style=''>allowing</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>interventions</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>initiated</span> <span style=''>that</span> <span style=''>promote</span> <span style='background-color:rgba(0, 255, 0, 0.4457831325301206);'>development</span> <span style=''>and</span> <span style=''>improve</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>prognosis</span> <span style=''>Research</span> <span style=''>on</span> <span style=''>autism</span> <span style=''>spectrum</span> <span style=''>disorder</span> <span style=''>(ASD)</span> <span style=''>suggests</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behavioral</span> <span style=''>markers</span> <span style=''>can</span> <span style=''>be</span> <span style=''>observed</span> <span style=''>late</span> <span style=''>in</span> <span style=''>the</span> <span style=''>first</span> <span style=''>year</span> <span style=''>of</span> <span style=''>life</span> <span style=''>Many</span> <span style=''>of</span> <span style=''>these</span> <span style=''>studies</span> <span style=''>involved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style=''>frame</span> <span style=''>by</span> <span style=''>frame</span> <span style=''>video</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>a</span> <span style=''>childs</span> <span style=''>natural</span> <span style=''>behavior</span> <span style=''>Although</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>intrusive</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensive</span> <span style=''>and</span> <span style=''>require</span> <span style=''>a</span> <span style=''>high</span> <span style=''>level</span> <span style=''>of</span> <span style=''>observer</span> <span style=''>training</span> <span style=''>thus</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impractical</span> <span style=''>for</span> <span style=''>clinical</span> <span style=''>and</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>research</span> <span style=''>purposes</span> <span style='background-color:rgba(0, 255, 0, 0.35714285714285715);'>Diagnostic</span> <span style=''>measures</span> <span style=''>for</span> <span style=''>ASD</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>for</span> <span style=''>infants</span> <span style=''>but</span> <span style=''>are</span> <span style=''>only</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style=''>Sparse</span> <span style=''>PCA</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Procrustes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reformulation</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>matrix</span> <span style=''>attracts</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>those</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>set</span> <span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>as</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>problem</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>a</span> <span style=''>penalty</span> <span style=''>term</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encourages</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>solution</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>methods</span> <span style=''>achieve</span> <span style=''>sparsity</span> <span style=''>at</span> <span style=''>the</span> <span style=''>expense</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sacrificing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style=''>property</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>dominant</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>without</span> <span style=''>trading</span> <span style=''>off</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>highly</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>hard</span> <span style=''>to</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Profiling</span> <span style=''>of</span> <span style=''>a</span> <span style=''>network</span> <span style=''>behind</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666665);'>infectious</span> <span style=''>disease</span> <span style=''>outbreak</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Stochasticity</span> <span style=''>and</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.5714285714285714);'>heterogeneity</span> <span style=''>are</span> <span style=''>of</span> <span style=''>great</span> <span style=''>interest</span> <span style=''>recently</span> <span style=''>in</span> <span style=''>studying</span> <span style=''>the</span> <span style=''>spread</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666665);'>infectious</span> <span style=''>disease</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>presented</span> <span style=''>method</span> <span style=''>solves</span> <span style=''>an</span> <span style=''>inverse</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.39560439560439553);'>effectively</span> <span style=''>decisive</span> <span style=''>topology</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style=''>network</span> <span style=''>and</span> <span style=''>reveal</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>transmission</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>govern</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.36585365853658547);'>stochastic</span> <span style=''>spreads</span> <span style=''>over</span> <span style=''>the</span> <span style=''>network</span> <span style=''>from</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666665);'>infectious</span> <span style=''>disease</span> <span style=''>outbreak</span> <span style=''>in</span> <span style=''>the</span> <span style=''>early</span> <span style=''>growth</span> <span style=''>phase</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Populations</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>epidemiological</span> <span style=''>compartment</span> <span style=''>models</span> <span style=''>and</span> <span style=''>a</span> <span style=''>meta</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>network</span> <span style=''>model</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.36585365853658547);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style=''>and</span> <span style=''>used</span> <span style=''>for</span> <span style=''>the</span> <span style=''>maximal</span> <span style='background-color:rgba(255, 0, 0, 0.49606299212598426);'>likelihood< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Region</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representation</span> <span style=''>A</span> <span style=''>novel</span> <span style=''>model</span> <span style=''>for</span> <span style=''>decoding</span> <span style=''>visual</span> <span style=''>stimuli</span> <span style=''>in</span> <span style=''>human</span> <span style=''>brains</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Pattern</span> <span style=''>(MVP)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>holds</span> <span style=''>enormous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>for</span> <span style=''>decoding</span> <span style=''>visual</span> <span style=''>stimuli</span> <span style=''>in</span> <span style=''>the</span> <span style=''>human</span> <span style=''>brain</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>employing</span> <span style=''>task</span> <span style=''>based</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>There</span> <span style=''>is</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>in</span> <span style=''>the</span> <span style=''>MVP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>ie</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreasing</span> <span style=''>noise</span> <span style=''>and</span> <span style=''>sparsity</span> <span style=''>defining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>(ROIs)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualizing</span> <span style=''>results</span> <span style=''>and</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>studies</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overcoming</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>model</span> <span style=''>of</span> <span style=''>neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>which</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>detect</span> <span style=''>the</span> <span style=''>active</span> <span style=''>regions</span> <span style=''>for</span> <span style=''>each</span> <span style=''>visual</span> <span style=''>stimulus</span> <span style=''>and</span> <span style=''>then</span> <span style=''>utilize</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anatomical</span> <span style=''>regions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualizing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activities</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>this</span> <span style=''>model</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>opportunity</span> <span style=''>for</span> <span style='background-col ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.0953058321479374)
# 	experimental (0.13655761024182078)
# 	architecture (0.07965860597439545)
# 	processing (0.10312944523470839)
# 	segmentation (0.07112375533428165)
# 	information (0.2553342816500711)
# 	different (0.25889046941678523)
# 	detection (0.13086770981507823)
# 	recognition (0.13300142247510668)
# 	convolutional (0.1386913229018492)
#
# Some Statistics words are:
# 	variables (0.14587525150905434)
# 	estimation (0.17253521126760563)
# 	stochastic (0.14084507042253522)
# 	statistical (0.15845070422535212)
# 	algorithm (0.39436619718309857)
# 	theoretical (0.1529175050301811)
# 	distribution (0.17655935613682092)
# 	inference (0.20271629778672032)
# 	dimensional (0.19617706237424548)
# 	regression (0.1836016096579477)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4b1b56fe-a10c-4bf2-87c3-7249179a16f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b1b56fe-a10c-4bf2-87c3-7249179a16f8")) {                    Plotly.newPlot(                        "4b1b56fe-a10c-4bf2-87c3-7249179a16f8",                        [{"x":["significant","analytically","tentative","knowledge","solutions","application","tractable","impossible","statistical","algorithms","learnability","detection","variables","relational","experimental","expressiveness","introduced","predictors","stability","theoretical","definitions","representative","operational","overarching","supervision","nevertheless","requirements","mathematical","framework","comprehensive","formulated","monitoring","contradictory","variation","objective","benchmark","conclusions","individual","potential","dominates","acceleration","exceptions","evolutionary","operators","individuals","restrictions","different","particular","dominated","introduces","crossover","restriction","population","validated","optimization","generating","recombination","constrained","preferably","dominance","offspring","asymptotic","traditional","outperforms","approaches","independent","important","constructed","practical","parametric","restrictive","techniques","distortion","dimensional","technique","regression","extremely","evaluating","performing","supported","coefficients","returning","developed","performances","contribution","functions","regularly","realistic","releasing","scenarios","applications","polynomials","attribute","combination","structure","properties","algorithm","intuition","conditional","computational","neuroscience","predictive","covariate","information","procedure","estimated","conditioned","naturally","simulation","dictionary","multivariate","experiments","parameter","successfully","technical","curvilinear","constraints","modalities","polynomial","illustrates","extraction","appropriate","introducing","minimization","interpreted","identified","generalization","principal","dimensionality","originated","projection","decorrelation","dedicated","frontiers","nonlinear","invertible","reduction","alternatives","corresponding","distances","philosophy","substantially","sequential","unsupervised","companion","injecting","disentangling","bottleneck","minimizing","activations","interpretation","representations","alternative","statistics","correlation","equivalent","explicitly","minimality","criterion","lagrangian","representation","overfitting","therefore","predicting","transitions","emergence","underfitting","invariant","established","regularizing","architecture","implicitly","memorization","invariance","principles","searching","engineering","exhaustive","automatically","demonstrated","prediction","necessarily","efficient","predictions","negligible","classification","complexity","superiority","interactions","subsequently","uniformly","empirically","structures","approximately","approximate","programming","formulations","computation","discussed","treewidth","selecting","collection","relationship","normalized","laplacian","performance","assumption","overcoming","hypergraph","symmetric","experiment","supervised","expression","functional","represent","classifying","regarding","surveying","specifically","usefulness","numerical","presented","representing","preprocessing","selection","significantly","initialization","effectiveness","indispensable","classifier","partitions","competitive","bandwidth","anomalies","resulting","automatic","detecting","description","estimates","convergence","consistent","exponentially","characterization","identifies","attention","characteristic","exponential","discrepancy","distributions","probability","hausdorff","hypothesis","constraint","continuous","annotated" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	frontiers
# 	exchangeable
# 	bootstraps
# 	deteriorates
# 	normality
# 	underdetermined
# 	schizophrenia
# 	methylation
# 	randomforest
# 	robustify
# 	polyhedral
# 	corollary
# 	nonstationary
# 	seasonality
# 	representer
# 	restaurant
# 	confounders
# 	protecting
# 	precipitation
# 	assimilation
# Some words which never appear in Statistics papers:
# 	tentative
# 	contradictory
# 	exceptions
# 	crossover
# 	offspring
# 	minimality
# 	underfitting
# 	treewidth
# 	navigation
# 	abstractions
# 	reversible
# 	neocortex
# 	superintelligent
# 	presently
# 	inherited
# 	silhouettes
# 	undertake
# 	opinionated
# 	surpassing
# 	referencing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0596010280259455e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.73
